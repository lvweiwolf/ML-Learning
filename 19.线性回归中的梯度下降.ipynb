# %% [markdown]
# # 线性回归中的梯度下降

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = 2 * np.random.random(size=100)
y = x * 3. + 4. + np.random.normal(size=100)

# %%
X = x.reshape(-1, 1)
X
# Out:
# array([[1.78990428],
#        [0.42007725],
#        [1.56941129],
#        [1.04457104],
#        [0.09422655],
#        [0.87051587],
#        [0.7373747 ],
#        [1.13867874],
#        [0.51945351],
#        [1.81305093],
#        [1.2828051 ],
#        [1.38603946],
#        [0.59539704],
#        [0.1759866 ],
#        [0.80054073],
#        [1.74136799],
#        [1.96798894],
#        [1.16032034],
#        [0.94624939],
#        [0.24765736],
#        [1.22591854],
#        [1.32980588],
#        [0.53061893],
#        [1.15967152],
#        [1.87703565],
#        [0.32095708],
#        [1.25363958],
#        [0.12276926],
#        [0.8838747 ],
#        [1.49361855],
#        [1.90456023],
#        [1.62362776],
#        [1.24498036],
#        [0.62766601],
#        [1.8523065 ],
#        [1.43063655],
#        [1.94329857],
#        [0.99853563],
#        [1.83011681],
#        [0.2472008 ],
#        [1.87382759],
#        [1.89900309],
#        [0.44166503],
# ...
